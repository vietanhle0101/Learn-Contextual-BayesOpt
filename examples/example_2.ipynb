# %%
import pickle
import numpy as np
# import casadi as ca
from timeit import default_timer as timer
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from pyswarms.single.global_best import GlobalBestPSO
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from util import *
# from BayesOpt import *
from BayesOpt_torch import *
from myGP_torch import *
from examples.ex_fcn import *
import warnings
import logging
logging.disable(logging.CRITICAL)

#suppress warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # An example to test contextual Bayesian optimization
#
# In this example, we consider a parametric quadractic function, in which the mapping from contextual variables to solutions of optimization variables is discontinuous.
#
# $
# f(\mathbf{z}, \mathbf{t}) = \frac{1}{w_2+w_2} \left( w_1 (z_1^2 + z_2^2) +  w_2((z_1-t_1)^2 + (z_2-t_2)^2) \right)
# $
#
# where $w_1 = \frac{1}{1 + \exp\left( -10(t_1 - 0.5) \right)}$, $w_2 = \frac{1}{1 + \exp\left( -10(t_2 + 0.5) \right)}$.

# %%
class discontinuity(blackbox_fcn):
    def __init__(self):
        super().__init__()

    def evaluate_true(self, Z, T):
        T1, T2 = T
        loss1 = np.sum(Z**2)
        loss2 = np.sum((Z - np.array([T1, T2]))**2)
        # sharp switching, but continuous
        w1 = 1 / (1 + np.exp(-10*(T1-0.5))) # sigmoid centered at 0.5
        w2 = 1 / (1 + np.exp(-10*(T2+0.5))) # sigmoid centered at 0.5

        noise = np.random.normal(0, 0.01)  
        obj = (w1*loss1 + w2*loss2)/(w1+w2)
        return -obj + noise

# %%
# Bounds on the inputs variable
n_pts = 101
var_bounds = [(-5., 10.), (0., 15.)]
# Bounds on the context variable
ctx_bounds = [(-5., 5.), (-10., 10.)]
true_fcn = discontinuity()
training_params = {"max_iter": 200, "optimizer": "Adam", "num_restarts": 5}
CBO = Context_BayesOpt(2, 2, print_level=True, training_params=training_params)
CBO.set_feasible_set(var_bounds, ctx_bounds, n_pts)

# %%
OUTCOME = CBO.run_Outer(true_fcn, k_max = 30, k_init = 10, j_max = 30, j_init = 10, beta = 1e2, beta_rate=0.9, tol=1e-1, patience=3)
# Out:
# Iteration # 1
# Sample the context: [-4.4 -8.6]
# Bayes Opt proposes to sample  [ 7.45 11.85]
# Bayes Opt proposes to sample  [-0.5  9.6]
# Bayes Opt proposes to sample  [ 7.15 14.7 ]
# Bayes Opt proposes to sample  [7.75 1.35]
# Bayes Opt proposes to sample  [1.75 7.05]
# Bayes Opt proposes to sample  [-1.55  0.75]
# Bayes Opt proposes to sample  [-1.25 12.3 ]
# Bayes Opt proposes to sample  [ 8.2 12.3]
# Bayes Opt proposes to sample  [7.9 0.6]
# Bayes Opt proposes to sample  [7.15 6.75]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          5.32743084]
# Bayes Opt proposes to sample  [1.2204295 0.       ]
# Bayes Opt proposes to sample  [0.86448101 0.        ]
# Bayes Opt proposes to sample  [0.63468689 0.        ]
# Bayes Opt proposes to sample  [0.2899283  2.27198041]
# Bayes Opt proposes to sample  [0.3708192 0.       ]
# Bayes Opt proposes to sample  [0.20929518 0.        ]
# Bayes Opt proposes to sample  [0.07694759 0.        ]
# Bayes Opt proposes to sample  [0.11228038 2.14898213]
# Bayes Opt proposes to sample  [-0.07828974  0.        ]
# Bayes Opt proposes to sample  [0.00093823 0.        ]
# Bayes Opt proposes to sample  [-0.01200316  0.        ]
# Bayes Opt proposes to sample  [0.06709533 1.82082653]
# Bayes Opt proposes to sample  [-0.04173003  0.        ]
# Bayes Opt proposes to sample  [-0.01127494  0.        ]
# Bayes Opt proposes to sample  [-0.00898056  0.        ]
# Bayes Opt proposes to sample  [-0.00865525  0.        ]
# Converged after 28 iterations.
# Inner loop returns solution: [-0.01127494  0.        ]
# Iteration # 2
# Sample the context: [ 0.7 -3.8]
# Bayes Opt proposes to sample  [8.35 8.25]
# Bayes Opt proposes to sample  [ 7.3  11.55]
# Bayes Opt proposes to sample  [-0.35 11.55]
# Bayes Opt proposes to sample  [0.25 4.05]
# Bayes Opt proposes to sample  [-1.4   9.75]
# Bayes Opt proposes to sample  [-4.55  6.6 ]
# Bayes Opt proposes to sample  [6.55 4.8 ]
# Bayes Opt proposes to sample  [9.7  5.55]
# Bayes Opt proposes to sample  [7.6  2.25]
# Bayes Opt proposes to sample  [5.35 4.5 ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [1.39236375 0.        ]
# Bayes Opt proposes to sample  [0.59652884 0.        ]
# Bayes Opt proposes to sample  [0.3728597 0.       ]
# Bayes Opt proposes to sample  [0.21454429 0.        ]
# Bayes Opt proposes to sample  [-0.63028496  1.97297259]
# Bayes Opt proposes to sample  [1.80269013 0.        ]
# Bayes Opt proposes to sample  [-0.67733816  0.        ]
# Bayes Opt proposes to sample  [-0.09243731  0.        ]
# Bayes Opt proposes to sample  [0.83426936 0.        ]
# Bayes Opt proposes to sample  [-0.42706514  1.71517761]
# Bayes Opt proposes to sample  [-0.04362143  0.        ]
# Bayes Opt proposes to sample  [0.23885104 0.        ]
# Bayes Opt proposes to sample  [0.03857152 0.        ]
# Bayes Opt proposes to sample  [0.17150362 0.        ]
# Bayes Opt proposes to sample  [0.10504733 0.        ]
# Bayes Opt proposes to sample  [-0.2512001   1.31759269]
# Bayes Opt proposes to sample  [0.32290568 0.        ]
# Bayes Opt proposes to sample  [0.19703486 0.        ]
# Bayes Opt proposes to sample  [0.15556763 0.        ]
# Inner loop returns solution: [-0.09243731  0.        ]
# Iteration # 3
# Sample the context: [-1.2 -8.6]
# Bayes Opt proposes to sample  [ 7.9 10.2]
# Bayes Opt proposes to sample  [1.9  5.25]
# Bayes Opt proposes to sample  [ 0.7  14.85]
# Bayes Opt proposes to sample  [ 6.55 14.4 ]
# Bayes Opt proposes to sample  [10.   7.8]
# Bayes Opt proposes to sample  [3.85 2.85]
# Bayes Opt proposes to sample  [ 5.95 14.55]
# Bayes Opt proposes to sample  [-2.45 15.  ]
# Bayes Opt proposes to sample  [7.9 9.9]
# Bayes Opt proposes to sample  [ 8.95 12.3 ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [10.  0.]
# Bayes Opt proposes to sample  [-5.          5.82476093]
# Bayes Opt proposes to sample  [0.78950414 0.        ]
# Bayes Opt proposes to sample  [0.44976166 0.        ]
# Bayes Opt proposes to sample  [0.23982349 0.        ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [0.69993666 0.        ]
# Bayes Opt proposes to sample  [0.51482525 0.        ]
# Bayes Opt proposes to sample  [0.36492211 0.        ]
# Bayes Opt proposes to sample  [-0.31194711  2.23913633]
# Bayes Opt proposes to sample  [0.30986579 0.        ]
# Bayes Opt proposes to sample  [0.20407849 0.        ]
# Bayes Opt proposes to sample  [0.12559184 0.        ]
# Bayes Opt proposes to sample  [0.06957077 0.        ]
# Bayes Opt proposes to sample  [0.03084848 0.        ]
# Converged after 26 iterations.
# Inner loop returns solution: [0.03084848 0.        ]
# Iteration # 4
# Sample the context: [-4.5  9.6]
# Bayes Opt proposes to sample  [-2.45  8.7 ]
# Bayes Opt proposes to sample  [9.25 6.45]
# Bayes Opt proposes to sample  [-1.85  1.2 ]
# Bayes Opt proposes to sample  [ 7.9  10.35]
# Bayes Opt proposes to sample  [8.35 2.1 ]
# Bayes Opt proposes to sample  [6.55 7.35]
# Bayes Opt proposes to sample  [4.3 4.8]
# Bayes Opt proposes to sample  [-1.55 13.05]
# Bayes Opt proposes to sample  [ 1.9 10.8]
# Bayes Opt proposes to sample  [-3.35  5.55]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [-5.         8.6206875]
# Bayes Opt proposes to sample  [-5.         9.1095321]
# Bayes Opt proposes to sample  [-5.          9.35070908]
# Bayes Opt proposes to sample  [-5.          9.51603377]
# Bayes Opt proposes to sample  [-5.          5.64947067]
# Bayes Opt proposes to sample  [-5.         10.46442647]
# Bayes Opt proposes to sample  [-2.66396217  9.57435976]
# Bayes Opt proposes to sample  [-5.         10.10155907]
# Bayes Opt proposes to sample  [-5.          9.91904218]
# Bayes Opt proposes to sample  [-2.89882595  9.56672366]
# Bayes Opt proposes to sample  [-5.          9.71913823]
# Bayes Opt proposes to sample  [-5.         9.6599565]
# Bayes Opt proposes to sample  [-3.14436181  9.58041113]
# Bayes Opt proposes to sample  [-5.          9.58372449]
# Bayes Opt proposes to sample  [-5.          9.57366319]
# Bayes Opt proposes to sample  [-3.37147028  9.58903433]
# Bayes Opt proposes to sample  [-5.          9.54731732]
# Bayes Opt proposes to sample  [-5.          9.54834582]
# Bayes Opt proposes to sample  [-3.57161939  9.59084825]
# Inner loop returns solution: [-5.          9.54731732]
# Iteration # 5
# Sample the context: [-1.9 -0.4]
# Bayes Opt proposes to sample  [2.2  9.75]
# Bayes Opt proposes to sample  [-1.25  1.5 ]
# Bayes Opt proposes to sample  [2.35 8.55]
# Bayes Opt proposes to sample  [5.5 3.9]
# Bayes Opt proposes to sample  [5.05 1.95]
# Bayes Opt proposes to sample  [-0.5   7.35]
# Bayes Opt proposes to sample  [-0.35  7.2 ]
# Bayes Opt proposes to sample  [0.85 6.3 ]
# Bayes Opt proposes to sample  [7.75 3.75]
# Bayes Opt proposes to sample  [-4.4   0.45]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [10. 15.]
# Bayes Opt proposes to sample  [1.01472143 0.        ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          4.45852485]
# Bayes Opt proposes to sample  [-0.3284965  0.       ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-0.53683629  0.        ]
# Bayes Opt proposes to sample  [-0.82814642  0.        ]
# Bayes Opt proposes to sample  [-1.06930433  0.        ]
# Bayes Opt proposes to sample  [-1.27491332  0.        ]
# Bayes Opt proposes to sample  [-1.44917724  0.        ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-1.31474524  0.        ]
# Bayes Opt proposes to sample  [-1.42561068  0.        ]
# Bayes Opt proposes to sample  [-1.51591717  0.        ]
# Bayes Opt proposes to sample  [-1.58842741  0.        ]
# Bayes Opt proposes to sample  [-1.64571927  0.        ]
# Converged after 28 iterations.
# Inner loop returns solution: [-1.64571927  0.        ]
# Iteration # 6
# Sample the context: [-3.8 -6.6]
# Bayes Opt proposes to sample  [1.15 6.15]
# Bayes Opt proposes to sample  [-3.8 10.8]
# Bayes Opt proposes to sample  [4.3  1.95]
# Bayes Opt proposes to sample  [2.35 3.15]
# Bayes Opt proposes to sample  [ 6.25 10.05]
# Bayes Opt proposes to sample  [4.75 8.25]
# Bayes Opt proposes to sample  [-5.   11.55]
# Bayes Opt proposes to sample  [10.   9.6]
# Bayes Opt proposes to sample  [8.2  3.75]
# Bayes Opt proposes to sample  [8.2 0.6]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [0.69123775 0.        ]
# Bayes Opt proposes to sample  [0.49649228 0.        ]
# Bayes Opt proposes to sample  [-5.          3.44763449]
# Bayes Opt proposes to sample  [0.05189583 0.        ]
# Bayes Opt proposes to sample  [0.06068025 0.        ]
# Bayes Opt proposes to sample  [0.06374521 0.        ]
# Bayes Opt proposes to sample  [0.06354701 0.        ]
# Converged after 18 iterations.
# Inner loop returns solution: [0.06374521 0.        ]
# Iteration # 7
# Sample the context: [0.  5.8]
# Bayes Opt proposes to sample  [7.15 2.4 ]
# Bayes Opt proposes to sample  [8.5 3.3]
# Bayes Opt proposes to sample  [-3.2  8.7]
# Bayes Opt proposes to sample  [-5.  11.1]
# Bayes Opt proposes to sample  [-3.65  0.3 ]
# Bayes Opt proposes to sample  [2.2  7.65]
# Bayes Opt proposes to sample  [-3.35  6.  ]
# Bayes Opt proposes to sample  [4.  5.4]
# Bayes Opt proposes to sample  [7.9  1.35]
# Bayes Opt proposes to sample  [-4.7   7.05]
# Bayes Opt proposes to sample  [10. 15.]
# Bayes Opt proposes to sample  [ 0.53738164 15.        ]
# Bayes Opt proposes to sample  [1.54863297 0.        ]
# Bayes Opt proposes to sample  [-0.07687757  4.84268595]
# Bayes Opt proposes to sample  [-0.03500502  5.27958821]
# Bayes Opt proposes to sample  [-9.26898166e-04  5.55167111e+00]
# Bayes Opt proposes to sample  [0.02436935 5.72360254]
# Bayes Opt proposes to sample  [0.02819433 5.75218994]
# Bayes Opt proposes to sample  [0.02114708 5.72341576]
# Bayes Opt proposes to sample  [0.15472519 6.36626859]
# Bayes Opt proposes to sample  [-0.06063406  5.25252367]
# Bayes Opt proposes to sample  [-0.0242675   5.52777764]
# Bayes Opt proposes to sample  [0.06033337 5.98056662]
# Bayes Opt proposes to sample  [-0.02462951  5.55149369]
# Bayes Opt proposes to sample  [0.00918896 5.74115934]
# Bayes Opt proposes to sample  [0.0093232  5.74405982]
# Bayes Opt proposes to sample  [0.00913005 5.7445502 ]
# Bayes Opt proposes to sample  [0.00913744 5.74526757]
# Converged after 28 iterations.
# Inner loop returns solution: [0.00913744 5.74526757]
# Iteration # 8
# Sample the context: [4.7 1.6]
# Bayes Opt proposes to sample  [8.8 2.4]
# Bayes Opt proposes to sample  [1.3 5.4]
# Bayes Opt proposes to sample  [-3.65 10.8 ]
# Bayes Opt proposes to sample  [ 3.1  13.95]
# Bayes Opt proposes to sample  [ 5.05 11.55]
# Bayes Opt proposes to sample  [-3.65  5.25]
# Bayes Opt proposes to sample  [8.2 4.5]
# Bayes Opt proposes to sample  [-4.55  8.1 ]
# Bayes Opt proposes to sample  [ 6.7 11.1]
# Bayes Opt proposes to sample  [-0.5   8.55]
# Bayes Opt proposes to sample  [0.1057772 0.       ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [4.30896964 0.        ]
# Bayes Opt proposes to sample  [2.67512937 0.        ]
# Bayes Opt proposes to sample  [2.30615275 2.20414737]
# Bayes Opt proposes to sample  [2.7852235 0.       ]
# Bayes Opt proposes to sample  [2.22412126 2.15139968]
# Bayes Opt proposes to sample  [2.54322949 0.        ]
# Bayes Opt proposes to sample  [2.09206704 0.        ]
# Bayes Opt proposes to sample  [2.25433374 2.11255457]
# Bayes Opt proposes to sample  [3.45281242 0.        ]
# Bayes Opt proposes to sample  [1.70057932 0.        ]
# Bayes Opt proposes to sample  [2.23567221 1.9330667 ]
# Bayes Opt proposes to sample  [2.21984353 1.77703326]
# Bayes Opt proposes to sample  [2.37494412 0.        ]
# Bayes Opt proposes to sample  [2.22623755 1.64997518]
# Bayes Opt proposes to sample  [2.39814129 0.        ]
# Bayes Opt proposes to sample  [2.23491133 1.53853977]
# Bayes Opt proposes to sample  [2.23623265 1.43212017]
# Bayes Opt proposes to sample  [2.40350571 0.        ]
# Inner loop returns solution: [2.23623265 1.43212017]
# Iteration # 9
# Sample the context: [ 5. -6.]
# Bayes Opt proposes to sample  [0.55 8.25]
# Bayes Opt proposes to sample  [-2.6   3.75]
# Bayes Opt proposes to sample  [9.7 7.5]
# Bayes Opt proposes to sample  [5.5  9.15]
# Bayes Opt proposes to sample  [-4.7  1.2]
# Bayes Opt proposes to sample  [ 5.35 10.65]
# Bayes Opt proposes to sample  [7.75 8.85]
# Bayes Opt proposes to sample  [ 8.35 14.7 ]
# Bayes Opt proposes to sample  [3.85 8.55]
# Bayes Opt proposes to sample  [-0.35  1.05]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [10.  0.]
# Bayes Opt proposes to sample  [1.62639131 0.        ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [1.18904253 0.        ]
# Bayes Opt proposes to sample  [0.88448957 0.        ]
# Bayes Opt proposes to sample  [0.6572051 0.       ]
# Bayes Opt proposes to sample  [0.47493886 0.        ]
# Bayes Opt proposes to sample  [0.32914142 0.        ]
# Bayes Opt proposes to sample  [0.48342187 2.20747766]
# Bayes Opt proposes to sample  [0.04013367 0.        ]
# Bayes Opt proposes to sample  [0.03436818 0.        ]
# Bayes Opt proposes to sample  [0.37217775 1.92824281]
# Bayes Opt proposes to sample  [-0.06962143  0.        ]
# Bayes Opt proposes to sample  [-0.04060488  0.        ]
# Bayes Opt proposes to sample  [-0.02241769  0.        ]
# Bayes Opt proposes to sample  [-0.0107228  0.       ]
# Converged after 27 iterations.
# Inner loop returns solution: [-0.02241769  0.        ]
# Iteration # 10
# Sample the context: [ -0.7 -10. ]
# Bayes Opt proposes to sample  [4.6  0.75]
# Bayes Opt proposes to sample  [6.7 3.6]
# Bayes Opt proposes to sample  [4.3 0.6]
# Bayes Opt proposes to sample  [5.05 1.5 ]
# Bayes Opt proposes to sample  [0.1 3.3]
# Bayes Opt proposes to sample  [-4.85 11.7 ]
# Bayes Opt proposes to sample  [-0.35 10.5 ]
# Bayes Opt proposes to sample  [-2.6   9.75]
# Bayes Opt proposes to sample  [-3.05  9.6 ]
# Bayes Opt proposes to sample  [10.  3.]
# Bayes Opt proposes to sample  [10. 15.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-0.29221056  0.        ]
# Bayes Opt proposes to sample  [-5.          3.43832957]
# Bayes Opt proposes to sample  [-0.22103839  0.        ]
# Bayes Opt proposes to sample  [-0.13249556  0.        ]
# Bayes Opt proposes to sample  [-0.07057282  0.        ]
# Bayes Opt proposes to sample  [-0.0334438   2.57211146]
# Bayes Opt proposes to sample  [0.06853168 0.        ]
# Bayes Opt proposes to sample  [0.07067825 0.        ]
# Bayes Opt proposes to sample  [0.07107928 0.        ]
# Bayes Opt proposes to sample  [0.07045803 0.        ]
# Converged after 22 iterations.
# Inner loop returns solution: [0.07067825 0.        ]
# Iteration # 11
# Sample the context: [ 5. 10.]
# Bayes Opt proposes to sample  [ 1.45 13.2 ]
# Bayes Opt proposes to sample  [ 7.15 14.85]
# Bayes Opt proposes to sample  [10.    6.75]
# Bayes Opt proposes to sample  [3.4 5.7]
# Bayes Opt proposes to sample  [-2.   10.35]
# Bayes Opt proposes to sample  [-2.45 14.25]
# Bayes Opt proposes to sample  [ 6.85 10.5 ]
# Bayes Opt proposes to sample  [3.1  4.65]
# Bayes Opt proposes to sample  [-4.85 14.4 ]
# Bayes Opt proposes to sample  [8.35 4.05]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [4.09803986 0.        ]
# Bayes Opt proposes to sample  [1.00072985 4.69460299]
# Bayes Opt proposes to sample  [1.80351544 4.93633004]
# Bayes Opt proposes to sample  [2.26902874 5.13125691]
# Bayes Opt proposes to sample  [2.46556403 5.2165899 ]
# Bayes Opt proposes to sample  [2.51063216 5.2262731 ]
# Bayes Opt proposes to sample  [2.51856349 5.21776967]
# Bayes Opt proposes to sample  [2.52370473 5.20960651]
# Converged after 19 iterations.
# Inner loop returns solution: [2.52370473 5.20960651]
# Iteration # 12
# Sample the context: [-5.         3.5982993]
# Bayes Opt proposes to sample  [1.9 7.5]
# Bayes Opt proposes to sample  [ 3.85 14.1 ]
# Bayes Opt proposes to sample  [-1.85  7.5 ]
# Bayes Opt proposes to sample  [-4.1  4.5]
# Bayes Opt proposes to sample  [ 1.15 14.1 ]
# Bayes Opt proposes to sample  [-2.9  2.4]
# Bayes Opt proposes to sample  [-2.15  7.05]
# Bayes Opt proposes to sample  [-2.75 12.6 ]
# Bayes Opt proposes to sample  [-3.2   6.45]
# Bayes Opt proposes to sample  [-1.4  7.8]
# Bayes Opt proposes to sample  [10.  0.]
# Bayes Opt proposes to sample  [0.79847943 0.        ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          5.53242631]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          4.70072815]
# Bayes Opt proposes to sample  [-5.          4.27105766]
# Bayes Opt proposes to sample  [-5.          4.00827362]
# Bayes Opt proposes to sample  [-5.          3.83735888]
# Bayes Opt proposes to sample  [-5.          3.73017566]
# Bayes Opt proposes to sample  [-5.          3.66818688]
# Bayes Opt proposes to sample  [-3.21062313  2.91860121]
# Bayes Opt proposes to sample  [-5.          3.87637472]
# Bayes Opt proposes to sample  [-5.         3.7724488]
# Bayes Opt proposes to sample  [-5.          3.71171014]
# Bayes Opt proposes to sample  [-5.          3.67640195]
# Bayes Opt proposes to sample  [-3.58302173  3.14576714]
# Bayes Opt proposes to sample  [-5.          3.75743916]
# Bayes Opt proposes to sample  [-5.          3.72001921]
# Bayes Opt proposes to sample  [-5.          3.69473747]
# Inner loop returns solution: [-5.          3.66818688]
# Iteration # 13
# Sample the context: [ 0.5538873 10.       ]
# Bayes Opt proposes to sample  [-4.7  3.3]
# Bayes Opt proposes to sample  [5.65 3.75]
# Bayes Opt proposes to sample  [5.65 6.3 ]
# Bayes Opt proposes to sample  [ 5.8  12.75]
# Bayes Opt proposes to sample  [-4.25 11.4 ]
# Bayes Opt proposes to sample  [8.35 7.2 ]
# Bayes Opt proposes to sample  [9.1 8.4]
# Bayes Opt proposes to sample  [ 5.35 10.65]
# Bayes Opt proposes to sample  [9.1 9.6]
# Bayes Opt proposes to sample  [5.05 7.5 ]
# Bayes Opt proposes to sample  [-0.03748363  0.        ]
# Bayes Opt proposes to sample  [-0.47332609  6.7699616 ]
# Bayes Opt proposes to sample  [10.  0.]
# Bayes Opt proposes to sample  [-2.33405458e-03  5.98258260e+00]
# Bayes Opt proposes to sample  [0.14267816 6.04065172]
# Bayes Opt proposes to sample  [0.23775534 6.05730063]
# Bayes Opt proposes to sample  [0.30752361 6.05856182]
# Bayes Opt proposes to sample  [0.36086809 6.05333379]
# Converged after 18 iterations.
# Inner loop returns solution: [0.30752361 6.05856182]
# Iteration # 14
# Sample the context: [-5.          0.95195895]
# Bayes Opt proposes to sample  [ 2.95 10.05]
# Bayes Opt proposes to sample  [4. 9.]
# Bayes Opt proposes to sample  [10.   8.7]
# Bayes Opt proposes to sample  [ 8.05 12.  ]
# Bayes Opt proposes to sample  [5.2  7.95]
# Bayes Opt proposes to sample  [ 1.  10.8]
# Bayes Opt proposes to sample  [ 3.85 14.1 ]
# Bayes Opt proposes to sample  [-3.65  5.1 ]
# Bayes Opt proposes to sample  [-0.05  3.75]
# Bayes Opt proposes to sample  [8.2 5.4]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [1.35836857 0.        ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          4.18239136]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-2.07579924  0.        ]
# Bayes Opt proposes to sample  [-5.          3.44858022]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          2.99189083]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          2.63722932]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-2.98867631  0.        ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          2.23885072]
# Bayes Opt proposes to sample  [-5.          2.03473282]
# Bayes Opt proposes to sample  [-5.  0.]
# Inner loop returns solution: [-5.  0.]
# Iteration # 15
# Sample the context: [-5. 10.]
# Bayes Opt proposes to sample  [ 6.55 12.9 ]
# Bayes Opt proposes to sample  [4.45 6.9 ]
# Bayes Opt proposes to sample  [4.9  9.75]
# Bayes Opt proposes to sample  [-2.9   9.75]
# Bayes Opt proposes to sample  [7.  5.4]
# Bayes Opt proposes to sample  [-0.05  0.  ]
# Bayes Opt proposes to sample  [5.2  4.35]
# Bayes Opt proposes to sample  [ 6.4  13.95]
# Bayes Opt proposes to sample  [ 0.7  10.35]
# Bayes Opt proposes to sample  [-4.4   8.85]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          9.02324553]
# Bayes Opt proposes to sample  [-5.         10.00204365]
# Bayes Opt proposes to sample  [-1.76249578 15.        ]
# Bayes Opt proposes to sample  [-5.         10.50588043]
# Bayes Opt proposes to sample  [-5.          9.06053143]
# Bayes Opt proposes to sample  [-5.         11.12088377]
# Bayes Opt proposes to sample  [-5.          8.82437441]
# Bayes Opt proposes to sample  [-5.         11.05678316]
# Bayes Opt proposes to sample  [-5.         10.51642625]
# Bayes Opt proposes to sample  [-5.          9.06996297]
# Bayes Opt proposes to sample  [-3.27845998  9.64083727]
# Bayes Opt proposes to sample  [-5.         10.71976304]
# Bayes Opt proposes to sample  [-5.         10.42109288]
# Bayes Opt proposes to sample  [-5.         10.15411348]
# Bayes Opt proposes to sample  [-5.         10.08547215]
# Bayes Opt proposes to sample  [-5.         10.08592881]
# Bayes Opt proposes to sample  [-5.         10.08466856]
# Converged after 29 iterations.
# Inner loop returns solution: [-5.         10.08547215]
# Iteration # 16
# Sample the context: [-5.        5.021914]
# Bayes Opt proposes to sample  [ 2.05 13.05]
# Bayes Opt proposes to sample  [-2.   9.6]
# Bayes Opt proposes to sample  [-3.5  10.65]
# Bayes Opt proposes to sample  [5.5 8.1]
# Bayes Opt proposes to sample  [-2.15  9.9 ]
# Bayes Opt proposes to sample  [7.6 3.6]
# Bayes Opt proposes to sample  [-1.85  0.75]
# Bayes Opt proposes to sample  [-1.4  14.55]
# Bayes Opt proposes to sample  [-2.   6.3]
# Bayes Opt proposes to sample  [-3.65  0.75]
# Bayes Opt proposes to sample  [10. 15.]
# Bayes Opt proposes to sample  [-5.          4.57556048]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          6.19317161]
# Bayes Opt proposes to sample  [-5.         5.7741444]
# Bayes Opt proposes to sample  [-5.          5.52040386]
# Bayes Opt proposes to sample  [-5.          5.35017028]
# Bayes Opt proposes to sample  [-2.13057207  4.55105418]
# Bayes Opt proposes to sample  [-5.          5.35839715]
# Bayes Opt proposes to sample  [-5.         5.2458442]
# Bayes Opt proposes to sample  [-5.          5.17472821]
# Bayes Opt proposes to sample  [-5.          5.13051402]
# Bayes Opt proposes to sample  [-5.          5.10287531]
# Converged after 23 iterations.
# Inner loop returns solution: [-5.          5.17472821]
# Iteration # 17
# Sample the context: [-5.         0.1080652]
# Bayes Opt proposes to sample  [-0.5  5.7]
# Bayes Opt proposes to sample  [ 6.4 11.7]
# Bayes Opt proposes to sample  [0.55 8.4 ]
# Bayes Opt proposes to sample  [ 9.7  11.25]
# Bayes Opt proposes to sample  [ 7.15 13.8 ]
# Bayes Opt proposes to sample  [1.45 7.05]
# Bayes Opt proposes to sample  [ 3.4  12.45]
# Bayes Opt proposes to sample  [-2.75  1.35]
# Bayes Opt proposes to sample  [-2.45 13.35]
# Bayes Opt proposes to sample  [7.15 0.75]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          5.53941608]
# Bayes Opt proposes to sample  [-1.07368922  0.        ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-1.42517052  0.        ]
# Bayes Opt proposes to sample  [-5.          3.27266922]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          2.65256249]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-2.5636203  0.       ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Converged after 28 iterations.
# Inner loop returns solution: [-5.  0.]
# Iteration # 18
# Sample the context: [ 4.8935733 10.       ]
# Bayes Opt proposes to sample  [9.4  8.85]
# Bayes Opt proposes to sample  [ 5.05 12.45]
# Bayes Opt proposes to sample  [-0.65 10.2 ]
# Bayes Opt proposes to sample  [3.4  0.15]
# Bayes Opt proposes to sample  [7.6 2.7]
# Bayes Opt proposes to sample  [-3.65 11.55]
# Bayes Opt proposes to sample  [ 5.35 11.55]
# Bayes Opt proposes to sample  [ 9.55 11.55]
# Bayes Opt proposes to sample  [4.9  6.15]
# Bayes Opt proposes to sample  [ 4.45 14.1 ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [0.56177187 4.6803269 ]
# Bayes Opt proposes to sample  [2.22146612 4.89184814]
# Bayes Opt proposes to sample  [2.38048403 5.00439437]
# Bayes Opt proposes to sample  [2.47741073 5.06995886]
# Bayes Opt proposes to sample  [2.5329126  5.10763348]
# Bayes Opt proposes to sample  [2.55690839 5.12643523]
# Converged after 17 iterations.
# Inner loop returns solution: [2.47741073 5.06995886]
# Iteration # 19
# Sample the context: [-5. 10.]
# Bayes Opt proposes to sample  [ 9.55 11.7 ]
# Bayes Opt proposes to sample  [5.2 2.1]
# Bayes Opt proposes to sample  [ 9.4  10.65]
# Bayes Opt proposes to sample  [ 9.1  12.15]
# Bayes Opt proposes to sample  [ 8.5  12.45]
# Bayes Opt proposes to sample  [2.65 6.45]
# Bayes Opt proposes to sample  [9.4 7.5]
# Bayes Opt proposes to sample  [-0.65  3.45]
# Bayes Opt proposes to sample  [0.1 9.3]
# Bayes Opt proposes to sample  [-3.5  0.6]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [ 0.32853487 15.        ]
# Bayes Opt proposes to sample  [-5.          8.24808867]
# Bayes Opt proposes to sample  [-5.          9.34568365]
# Bayes Opt proposes to sample  [-5.         9.7154089]
# Bayes Opt proposes to sample  [-5.         10.03961972]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [-5.          9.05996266]
# Bayes Opt proposes to sample  [-2.95895573 10.36126347]
# Bayes Opt proposes to sample  [-5.          9.30264772]
# Bayes Opt proposes to sample  [-5.          9.69788611]
# Bayes Opt proposes to sample  [-3.16711816 10.34851   ]
# Bayes Opt proposes to sample  [-5.          9.68056195]
# Bayes Opt proposes to sample  [-5.          9.86860553]
# Bayes Opt proposes to sample  [-5.          9.95051636]
# Bayes Opt proposes to sample  [-3.4164303 10.2819972]
# Bayes Opt proposes to sample  [-5.          9.86563325]
# Bayes Opt proposes to sample  [-5.          9.93062449]
# Bayes Opt proposes to sample  [-5.          9.96386248]
# Bayes Opt proposes to sample  [-5.          9.98152919]
# Converged after 30 iterations.
# Inner loop returns solution: [-5.          9.98152919]
# Iteration # 20
# Sample the context: [-1.7617168 10.       ]
# Bayes Opt proposes to sample  [0.25 0.6 ]
# Bayes Opt proposes to sample  [7.3 8.7]
# Bayes Opt proposes to sample  [0.7 1.5]
# Bayes Opt proposes to sample  [4.9 2.4]
# Bayes Opt proposes to sample  [3.85 3.  ]
# Bayes Opt proposes to sample  [-0.5   3.75]
# Bayes Opt proposes to sample  [4.75 9.9 ]
# Bayes Opt proposes to sample  [3.55 1.5 ]
# Bayes Opt proposes to sample  [8.05 5.85]
# Bayes Opt proposes to sample  [-2.15  2.25]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [10. 15.]
# Bayes Opt proposes to sample  [-5.          9.11382679]
# Bayes Opt proposes to sample  [ 0.43147581 15.        ]
# Bayes Opt proposes to sample  [-1.33385582  9.99014521]
# Bayes Opt proposes to sample  [-1.41871516  9.94902617]
# Bayes Opt proposes to sample  [-1.4698746   9.94591162]
# Bayes Opt proposes to sample  [-1.51049006  9.94807954]
# Converged after 18 iterations.
# Inner loop returns solution: [-1.51049006  9.94807954]
# Iteration # 21
# Sample the context: [5.        4.6365066]
# Bayes Opt proposes to sample  [8.5 3. ]
# Bayes Opt proposes to sample  [-0.8  8.1]
# Bayes Opt proposes to sample  [ 0.85 10.65]
# Bayes Opt proposes to sample  [3.55 1.35]
# Bayes Opt proposes to sample  [-2.6  2.7]
# Bayes Opt proposes to sample  [-2.75 11.25]
# Bayes Opt proposes to sample  [3.25 8.7 ]
# Bayes Opt proposes to sample  [ 1.45 10.05]
# Bayes Opt proposes to sample  [3.7  5.55]
# Bayes Opt proposes to sample  [10.   13.05]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [2.71617362 0.        ]
# Bayes Opt proposes to sample  [10.  0.]
# Bayes Opt proposes to sample  [1.89917729 0.        ]
# Bayes Opt proposes to sample  [2.08583148 2.99460889]
# Bayes Opt proposes to sample  [2.27217782 2.87509215]
# Bayes Opt proposes to sample  [2.37325289 2.77936005]
# Bayes Opt proposes to sample  [2.43233147 2.69890037]
# Bayes Opt proposes to sample  [2.62981872 0.        ]
# Bayes Opt proposes to sample  [2.43422743 2.80963527]
# Bayes Opt proposes to sample  [2.4625703  2.74535474]
# Bayes Opt proposes to sample  [2.48054938 2.69005629]
# Bayes Opt proposes to sample  [2.49211244 2.64276858]
# Converged after 23 iterations.
# Inner loop returns solution: [2.49211244 2.64276858]
# Iteration # 22
# Sample the context: [ 2.168032 10.      ]
# Bayes Opt proposes to sample  [5.35 7.5 ]
# Bayes Opt proposes to sample  [-1.1  6.3]
# Bayes Opt proposes to sample  [4.15 8.85]
# Bayes Opt proposes to sample  [-1.25  3.  ]
# Bayes Opt proposes to sample  [ 0.1 15. ]
# Bayes Opt proposes to sample  [-1.7   9.75]
# Bayes Opt proposes to sample  [8.5  7.95]
# Bayes Opt proposes to sample  [ 3.85 11.55]
# Bayes Opt proposes to sample  [2.35 5.7 ]
# Bayes Opt proposes to sample  [ 4.3  14.55]
# Bayes Opt proposes to sample  [10.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [2.10725827 0.        ]
# Bayes Opt proposes to sample  [-5.          7.29428395]
# Bayes Opt proposes to sample  [1.32146181 4.68127891]
# Bayes Opt proposes to sample  [1.21681128 4.77987582]
# Bayes Opt proposes to sample  [1.15884261 4.85002904]
# Bayes Opt proposes to sample  [1.12438557 4.90255034]
# Bayes Opt proposes to sample  [1.10390939 4.94247769]
# Converged after 19 iterations.
# Inner loop returns solution: [1.10390939 4.94247769]
# Iteration # 23
# Sample the context: [-0.6826856 10.       ]
# Bayes Opt proposes to sample  [6.85 0.  ]
# Bayes Opt proposes to sample  [2.2  6.45]
# Bayes Opt proposes to sample  [0.4 6.6]
# Bayes Opt proposes to sample  [2.65 5.7 ]
# Bayes Opt proposes to sample  [ 1.  13.2]
# Bayes Opt proposes to sample  [-3.2   9.15]
# Bayes Opt proposes to sample  [8.2 2.1]
# Bayes Opt proposes to sample  [2.8  8.25]
# Bayes Opt proposes to sample  [4.3 6.6]
# Bayes Opt proposes to sample  [2.35 5.55]
# Bayes Opt proposes to sample  [10. 15.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [-5.         8.7573397]
# Bayes Opt proposes to sample  [-0.55565514 10.90581347]
# Bayes Opt proposes to sample  [-0.64196474 10.63254647]
# Bayes Opt proposes to sample  [-0.7224668  10.41940058]
# Bayes Opt proposes to sample  [-0.7753109  10.26189679]
# Bayes Opt proposes to sample  [-0.796621   10.15505656]
# Bayes Opt proposes to sample  [-0.79266389 10.08835314]
# Bayes Opt proposes to sample  [-0.77512994 10.04729996]
# Bayes Opt proposes to sample  [-0.75395286 10.01932544]
# Converged after 22 iterations.
# Inner loop returns solution: [-0.75395286 10.01932544]
# Iteration # 24
# Sample the context: [ 1.1070904 10.       ]
# Bayes Opt proposes to sample  [-0.35  3.3 ]
# Bayes Opt proposes to sample  [ 4.75 13.05]
# Bayes Opt proposes to sample  [-4.55  2.1 ]
# Bayes Opt proposes to sample  [1.75 1.95]
# Bayes Opt proposes to sample  [ 7.45 13.35]
# Bayes Opt proposes to sample  [ 9.4  12.75]
# Bayes Opt proposes to sample  [8.35 4.35]
# Bayes Opt proposes to sample  [7.75 6.  ]
# Bayes Opt proposes to sample  [1.6 3.9]
# Bayes Opt proposes to sample  [3.4 5.7]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [10.  0.]
# Bayes Opt proposes to sample  [-5.          7.48657506]
# Bayes Opt proposes to sample  [-4.31374629e-03  6.96089502e+00]
# Bayes Opt proposes to sample  [0.15609627 6.29903322]
# Bayes Opt proposes to sample  [0.369983 0.      ]
# Bayes Opt proposes to sample  [0.3425292  5.61159491]
# Bayes Opt proposes to sample  [0.40784674 5.45629592]
# Bayes Opt proposes to sample  [0.45818999 5.34129862]
# Bayes Opt proposes to sample  [0.4966274  5.25604476]
# Bayes Opt proposes to sample  [0.52573011 5.19289871]
# Bayes Opt proposes to sample  [0.54741065 5.14657916]
# Converged after 22 iterations.
# Inner loop returns solution: [0.54741065 5.14657916]
# Iteration # 25
# Sample the context: [-1.0802687 10.       ]
# Bayes Opt proposes to sample  [ 4.   10.65]
# Bayes Opt proposes to sample  [9.55 9.  ]
# Bayes Opt proposes to sample  [5.35 4.8 ]
# Bayes Opt proposes to sample  [3.85 8.4 ]
# Bayes Opt proposes to sample  [8.05 8.55]
# Bayes Opt proposes to sample  [8.65 8.1 ]
# Bayes Opt proposes to sample  [0.1 6.6]
# Bayes Opt proposes to sample  [10.   14.85]
# Bayes Opt proposes to sample  [8.5  1.05]
# Bayes Opt proposes to sample  [-4.4   1.65]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [-5.          8.77548927]
# Bayes Opt proposes to sample  [ 0.45979968 15.        ]
# Bayes Opt proposes to sample  [-1.39263248 10.11749276]
# Bayes Opt proposes to sample  [-1.30067095 10.06245735]
# Bayes Opt proposes to sample  [-1.22843564 10.03751856]
# Bayes Opt proposes to sample  [-1.17048929 10.02328456]
# Converged after 17 iterations.
# Inner loop returns solution: [-1.17048929 10.02328456]
# Iteration # 26
# Sample the context: [ 0.09486331 10.        ]
# Bayes Opt proposes to sample  [-2.3   3.15]
# Bayes Opt proposes to sample  [-3.95  7.8 ]
# Bayes Opt proposes to sample  [9.7  4.05]
# Bayes Opt proposes to sample  [5.35 6.15]
# Bayes Opt proposes to sample  [-0.8   9.75]
# Bayes Opt proposes to sample  [4.9 8.7]
# Bayes Opt proposes to sample  [ 3.55 12.9 ]
# Bayes Opt proposes to sample  [6.55 8.55]
# Bayes Opt proposes to sample  [-3.2 10.5]
# Bayes Opt proposes to sample  [2.8 0.6]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [10. 15.]
# Bayes Opt proposes to sample  [ 0.78538833 15.        ]
# Bayes Opt proposes to sample  [0.16082077 9.33831552]
# Bayes Opt proposes to sample  [0.14778229 9.53979584]
# Bayes Opt proposes to sample  [0.15138249 9.6361005 ]
# Bayes Opt proposes to sample  [0.15817107 9.69370047]
# Bayes Opt proposes to sample  [0.165361   9.73074023]
# Converged after 18 iterations.
# Inner loop returns solution: [0.165361   9.73074023]
# Iteration # 27
# Sample the context: [-2.015289  5.36865 ]
# Bayes Opt proposes to sample  [-4.7   8.85]
# Bayes Opt proposes to sample  [1.3 7.5]
# Bayes Opt proposes to sample  [-5.   7.8]
# Bayes Opt proposes to sample  [ 1.75 14.25]
# Bayes Opt proposes to sample  [ 0.1  12.75]
# Bayes Opt proposes to sample  [ 4.75 13.5 ]
# Bayes Opt proposes to sample  [-2.15  9.45]
# Bayes Opt proposes to sample  [3.25 7.5 ]
# Bayes Opt proposes to sample  [3.85 4.5 ]
# Bayes Opt proposes to sample  [-2.9  4.8]
# Bayes Opt proposes to sample  [10.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [0.96524993 0.        ]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [-1.90704569  4.69954895]
# Bayes Opt proposes to sample  [-1.90876858  4.85977813]
# Bayes Opt proposes to sample  [-1.90818005  4.97020867]
# Bayes Opt proposes to sample  [-1.90725086  5.05312514]
# Bayes Opt proposes to sample  [-1.90643297  5.11748862]
# Bayes Opt proposes to sample  [-1.90583177  5.16821636]
# Converged after 20 iterations.
# Inner loop returns solution: [-1.90583177  5.16821636]
# Iteration # 28
# Sample the context: [ 0.3336698 10.       ]
# Bayes Opt proposes to sample  [6.55 8.85]
# Bayes Opt proposes to sample  [3.55 4.05]
# Bayes Opt proposes to sample  [7.45 1.95]
# Bayes Opt proposes to sample  [1.75 9.  ]
# Bayes Opt proposes to sample  [ 1.45 11.7 ]
# Bayes Opt proposes to sample  [0.7 5.1]
# Bayes Opt proposes to sample  [-0.8   4.95]
# Bayes Opt proposes to sample  [3.1 8.7]
# Bayes Opt proposes to sample  [-0.05  2.25]
# Bayes Opt proposes to sample  [3.1 1.5]
# Bayes Opt proposes to sample  [-5. 15.]
# Bayes Opt proposes to sample  [10. 15.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          8.44295233]
# Bayes Opt proposes to sample  [-0.42352707  9.21785887]
# Bayes Opt proposes to sample  [-0.25973274  9.03205697]
# Bayes Opt proposes to sample  [-0.14091687  8.90482869]
# Bayes Opt proposes to sample  [-0.04770134  8.81306093]
# Bayes Opt proposes to sample  [0.02678412 8.74564193]
# Bayes Opt proposes to sample  [0.08697767 8.69544481]
# Converged after 20 iterations.
# Inner loop returns solution: [0.08697767 8.69544481]
# Iteration # 29
# Sample the context: [-5.         0.3129465]
# Bayes Opt proposes to sample  [-3.35  7.05]
# Bayes Opt proposes to sample  [-0.35  0.6 ]
# Bayes Opt proposes to sample  [-0.8  11.55]
# Bayes Opt proposes to sample  [-4.25 10.8 ]
# Bayes Opt proposes to sample  [-2.6   8.85]
# Bayes Opt proposes to sample  [7.6  6.75]
# Bayes Opt proposes to sample  [ 7.3  11.85]
# Bayes Opt proposes to sample  [-0.2   2.85]
# Bayes Opt proposes to sample  [ 1.6  12.75]
# Bayes Opt proposes to sample  [0.4  8.25]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [10.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          2.80561679]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-1.71580442  0.        ]
# Bayes Opt proposes to sample  [-5.          2.62079444]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.          2.33985391]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-3.02468918  0.        ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [-5.  0.]
# Converged after 30 iterations.
# Inner loop returns solution: [-5.  0.]
# Iteration # 30
# Sample the context: [ 5.        -1.5414774]
# Bayes Opt proposes to sample  [-4.85  8.55]
# Bayes Opt proposes to sample  [-2.    6.75]
# Bayes Opt proposes to sample  [8.05 7.05]
# Bayes Opt proposes to sample  [ 9.85 10.65]
# Bayes Opt proposes to sample  [-3.65  9.  ]
# Bayes Opt proposes to sample  [-4.85  9.6 ]
# Bayes Opt proposes to sample  [6.7  1.95]
# Bayes Opt proposes to sample  [-2.   13.95]
# Bayes Opt proposes to sample  [-1.55 12.6 ]
# Bayes Opt proposes to sample  [6.55 5.4 ]
# Bayes Opt proposes to sample  [-5.  0.]
# Bayes Opt proposes to sample  [1.01350695 0.        ]
# Bayes Opt proposes to sample  [10.  0.]
# Bayes Opt proposes to sample  [0.63656175 0.        ]
# Bayes Opt proposes to sample  [0.41448764 0.        ]
# Bayes Opt proposes to sample  [-0.34549992  2.14758891]
# Bayes Opt proposes to sample  [0.46861034 0.        ]
# Bayes Opt proposes to sample  [0.25554525 0.        ]
# Bayes Opt proposes to sample  [-0.30851196  1.96953308]
# Bayes Opt proposes to sample  [0.27783989 0.        ]
# Bayes Opt proposes to sample  [0.08158825 0.        ]
# Bayes Opt proposes to sample  [-0.0045422  0.       ]
# Bayes Opt proposes to sample  [-0.2287053   1.73271945]
# Bayes Opt proposes to sample  [0.17028694 0.        ]
# Bayes Opt proposes to sample  [0.04261623 0.        ]
# Bayes Opt proposes to sample  [0.01445268 0.        ]
# Bayes Opt proposes to sample  [0.01222899 0.        ]
# Bayes Opt proposes to sample  [-0.14841887  1.40803814]
# Bayes Opt proposes to sample  [0.07248072 0.        ]
# Bayes Opt proposes to sample  [0.04565764 0.        ]
# Inner loop returns solution: [0.01445268 0.        ]

# %%
CBO.GP_s.training_params = {"max_iter": 1000, "optimizer": "Adam", "num_restarts": 5}
CBO.GP_s._train_gp(CBO.GP_s.X, CBO.GP_s.Y)

# %%
# Separate TT into T1, T2
T1 = CBO.TT[:, 0]
T2 = CBO.TT[:, 1]

Z_GP, _ = CBO.GP_s.predict(CBO.TT)
Z1 = Z_GP[:,0]; Z2 = Z_GP[:,1]
# Create a figure with two subplots (1 row, 2 columns)
fig, axs = plt.subplots(1, 2, figsize=(16, 6))

# Plot the first heatmap in the first subplot
c1 = axs[0].pcolormesh(T1.reshape(n_pts, n_pts), T2.reshape(n_pts, n_pts), Z1.reshape(n_pts, n_pts),
                       shading='auto', vmin=var_bounds[0][0], vmax=var_bounds[0][1])
axs[0].set_xlabel('T1')
axs[0].set_ylabel('T2')
axs[0].set_title('Heatmap of Z1 over (T1, T2)')
axs[0].plot(CBO.GP_s.X[:,0].cpu().numpy(), CBO.GP_s.X[:,1].cpu().numpy(), 'rx', markersize = 12)
fig.colorbar(c1, ax=axs[0])

# Plot the second heatmap in the second subplot
c2 = axs[1].pcolormesh(T1.reshape(n_pts, n_pts), T2.reshape(n_pts, n_pts), Z2.reshape(n_pts, n_pts),
                       shading='auto', vmin=var_bounds[1][0], vmax=var_bounds[1][1])
axs[1].set_xlabel('T1')
axs[1].set_ylabel('T2')
axs[1].set_title('Heatmap of Z2 over (T1, T2)')
axs[1].plot(CBO.GP_s.X[:,0].cpu().numpy(), CBO.GP_s.X[:,1].cpu().numpy(), 'rx', markersize = 12)
fig.colorbar(c2, ax=axs[1])

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Ground-truth from a solver

# %%
# # Using differential evolution and L-BFGS-B optimizer from SciPy, quite expensive
# from scipy.optimize import differential_evolution
# sample_T = CBO.TT
# best_Zsol = []

# for T in sample_T:
#     def obj(Z):
#         return -true_fcn.evaluate_true(Z, T)
#     # First global optimization
#     result_de = differential_evolution(obj, var_bounds)
#     # Then local refinement
#     res = minimize(obj, result_de.x, method='L-BFGS-B', bounds=var_bounds)
#     best_Zsol.append(res.x)

# best_Zsol = np.array(best_Zsol)

# %%
# Second option: using PSO optimizer
best_Zsol = []
sample_T = CBO.TT

# instantiate the optimizer
x_max = CBO.ZZ[-1]
x_min = CBO.ZZ[0]
bounds = (x_min, x_max)
options = {'c1': 0.5, 'c2': 0.3, 'w': 0.9}

for T in sample_T:
    # Define objective function for given T
    def objective(Z_particles):
        return -np.array([true_fcn.evaluate_true(Z, T).item() for Z in Z_particles])
    
    # Optimize with PSO
    optimizer = GlobalBestPSO(n_particles=30, dimensions=2, options=options, bounds=bounds)
    cost, pos = optimizer.optimize(objective, iters=100, verbose=False)
    # Add local refinement
    def single_obj(Z):
        return -true_fcn.evaluate_true(Z, T).item()

    res = minimize(single_obj, pos, method='L-BFGS-B', bounds=list(zip(x_min, x_max)))
    best_Zsol.append(res.x)

best_Zsol = np.array(best_Zsol)

# %%
# Separate TT into T1, T2
T1 = sample_T[:, 0]
T2 = sample_T[:, 1]

# Separate Z into Z1, Z2
Z1 = best_Zsol[:, 0]
Z2 = best_Zsol[:, 1]

# Create a figure with two subplots (1 row, 2 columns)
fig, axs = plt.subplots(1, 2, figsize=(16, 6))

# Plot the first heatmap (Z1) in the first subplot
c1 = axs[0].pcolormesh(T1.reshape(n_pts, n_pts), T2.reshape(n_pts, n_pts), Z1.reshape(n_pts, n_pts),
                       shading='auto', vmin=var_bounds[0][0], vmax=var_bounds[0][1])
axs[0].set_xlabel('T1')
axs[0].set_ylabel('T2')
axs[0].set_title('Heatmap of Z1 over (T1, T2)')
fig.colorbar(c1, ax=axs[0])

# Plot the second heatmap (Z2) in the second subplot
c2 = axs[1].pcolormesh(T1.reshape(n_pts, n_pts), T2.reshape(n_pts, n_pts), Z2.reshape(n_pts, n_pts),
                       shading='auto', vmin=var_bounds[1][0], vmax=var_bounds[1][1]) 
axs[1].set_xlabel('T1')
axs[1].set_ylabel('T2')
axs[1].set_title('Heatmap of Z2 over (T1, T2)')
fig.colorbar(c2, ax=axs[1])

# Adjust layout for better spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()
